# %% [markdown]
# <a href="https://colab.research.google.com/github/cojoclaudiu/Mathfs/blob/master/tema_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/cojoclaudiu/inteligenta-artificiala-fsega.git
# %cd inteligenta-artificiala-fsega
# Out:
# Cloning into 'inteligenta-artificiala-fsega'...
# warning: You appear to have cloned an empty repository.
# /content/inteligenta-artificiala-fsega
